# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # KEGG cpd classes
#
# Graph all KEGG compound classes on the same plot (with variance outlined)

# %%
#File paths (relative) to all csv files containing fragments & occurances over full KEGG database
antbio_fp = "Tests/Antibio_sampleOccurrances/0_fullOccurances.csv"
carb_fp = "Tests/Carbs_sampleOccurrances/0_fullOccurances.csv"
hormtrans_fp = "Tests/HormTrans_sampleOccurances/0_fullOccurances.csv"
lipid_fp = "Tests/Lipid_sampleOccurances/0_fullOccurances.csv"
nucAcids_fp = "Tests/NucAcids_sampleOccurances/0_fullOccurances.csv"
orgAcids_fp = "Tests/OrgAcids_sampleOccurances/0_fullOccurances.csv"
peptides_fp = "Tests/Peptides_sampleOccurances/0_fullOccurances.csv"
vitcofs_fp = "Tests/VotsCofs_sampleOccurances/0_fullOccurances.csv"

# %%
#Label dictionary
label_dict = {"Tests/Antibio_sampleOccurrances/0_fullOccurances.csv":"Antibiotics", 
             "Tests/Carbs_sampleOccurrances/0_fullOccurances.csv": "Carbohydrates",
             "Tests/HormTrans_sampleOccurances/0_fullOccurances.csv": "Hormones & Transmitters",
             "Tests/Lipid_sampleOccurances/0_fullOccurances.csv": "Lipids",
             "Tests/NucAcids_sampleOccurances/0_fullOccurances.csv": "Nucleic Acids",
             "Tests/OrgAcids_sampleOccurances/0_fullOccurances.csv": "Organic Acids",
             "Tests/Peptides_sampleOccurances/0_fullOccurances.csv": "Peptides",
             "Tests/VotsCofs_sampleOccurances/0_fullOccurances.csv": "Vitamins & Cofactors"}

# %%
#Hex color dictionary
color_dict = {"Tests/Antibio_sampleOccurrances/0_fullOccurances.csv":"#003f5c", 
             "Tests/Carbs_sampleOccurrances/0_fullOccurances.csv": "#2f4b7c",
             "Tests/HormTrans_sampleOccurances/0_fullOccurances.csv": "#665191",
             "Tests/Lipid_sampleOccurances/0_fullOccurances.csv": "#a05195",
             "Tests/NucAcids_sampleOccurances/0_fullOccurances.csv": "#d45087",
             "Tests/OrgAcids_sampleOccurances/0_fullOccurances.csv": "#f95d6a",
             "Tests/Peptides_sampleOccurances/0_fullOccurances.csv": "#ff7c43",
             "Tests/VotsCofs_sampleOccurances/0_fullOccurances.csv": "#ffa600"}

#Color palette from: https://learnui.design/tools/data-color-picker.html#palette

# %%
plt.figure(figsize=(6,6))

#Plot all classes on one space
for fp in [antbio_fp, carb_fp, hormtrans_fp, lipid_fp, nucAcids_fp, orgAcids_fp, peptides_fp, vitcofs_fp]:
    df = pd.read_csv(fp)
    
    occurances = df["Occurances"].tolist()
    yvals = sorted(list(map(int, occurances)), reverse=True)#, reverse=True)
    #xvals = range(0, len(yvals))
    xvals = np.linspace(0, 1, num=len(yvals))
    
    plt.plot(xvals, yvals, linewidth=3, label=label_dict[fp])

# plt.yscale("log")
# plt.xscale("log")
plt.ylabel("Occurances over KEGG")
plt.xlabel("Count")
plt.legend()
